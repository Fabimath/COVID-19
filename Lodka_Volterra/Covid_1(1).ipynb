# %% [markdown]
# # Cambiar los datos.
# Para el modelo de Lodka Volterra, cambiaremos los datos a las fechas de los casos del covid e y_1 y_2 se convertiran en total de infectados y muertos respectivamente.
#
# Cambiaremos `lynx.txt` por `covid.txt` en el mismo formato.

# %%
#######################################################################################################
## Estimation Lynx-Hare dynamics using Lotka-Volterra equation                                       ##   
## Estimates based on QL-ODE-P-splines (Frasso, Jaeger and Lambert, 2015)                            ##
#######################################################################################################

#-------------------------------------------- library -------------------------------------------------#

rm(list = ls()); graphics.off(); cat("\014")
library(splines)
library(Matrix)
library(spam)
library(deSolve)

#------------------------------------- source files ---------------------------------------------------#

source("basis_array.R")
source("functions_to_optimize.R")
source("penalty_function.R")

#------------------------------------------ data and time ---------------------------------------------#

dat = read.delim("covid.txt", header = F)
dat = dat[16:36, ]

t_obs = seq(0, 20, len = nrow(dat))
n = length(t_obs)

y_obs_1 = dat[, 2] 
y_obs_2 = dat[, 3] 
y_obs = c(y_obs_1, y_obs_2)

N_obs = n * 2

min_t = min(t_obs)
max_t = max(t_obs)

# %%
#------------------------------------- Basis matrices -------------------------------------------------#

length_t = 1e3 
seq_t = seq(min_t, max_t, length = length_t)
ndt = 200

B_seq_t = basis_array(x = seq_t, xl = min_t, xr = max_t, ndx = ndt, deg = 3, max_derivs = 2, sparse = TRUE)
for (j in 1:length(B_seq_t))
{
B_seq_t[[j]] = as.spam(as.matrix(B_seq_t[[j]]))
}

# %%
#------------------------------------- stoping rules --------------------------------------------------#

tol_gamma = 1e-4
tol_ck = 1e-4
tol_theta_tau = 1e-4

# %%
#-------------------------------- design matrix and diff pen ------------------------------------------#

B = basis_array(x = t_obs, xl = min_t, xr = max_t, ndx = ndt, deg = 3, max_derivs = 1, sparse = TRUE)
B_0 = as.spam(as.matrix(B[[1]]))
t_B_0 = t(B_0)

tB_B = t_B_0 %*% B_0

tB_y = t_B_0 %*% cbind(y_obs_1, y_obs_2)

M = dim(tB_B)[2]

D = diff(diag(M), diff = 2)
tD_D = t(D) %*% D

# %%
#------------------ Initial smoothing raw data and initial parameters ---------------------------------#

# smoothing for x1 and x2

las = seq(-1, 8, by = .5)
cv = ed = las * 0
i = 1

for(la in las)
{
  lam = 10 ^ la
  solve_A = solve(tB_B +  lam * tD_D)
  cy = solve_A %*% tB_y
  ed[i] = sum(diag(B_0 %*% solve_A %*% t_B_0))
  rss = sum((y_obs - B_0 %*% cy) ^ 2)
  cv[i] = rss/((N_obs - ed[i]) ^ 2)
  i = i + 1
}

lam_opt = 10 ^ las[which.min(cv)]
ck = c(solve(tB_B +  lam_opt * tD_D, tB_y))
tau_in = (N_obs - ed[which.min(cv)])/sum((y_obs - B_0 %*% matrix(ck, ncol = 2))^2)

# %% [markdown]
# En la siguiente linea de código el algoritmo se queda dentro del ciclo while. La pregunta es ¿Mi computador no es tan potente?, ¿Hay algo que haga que no salga del ciclo while?

# %%
#--------------------------------- Quasi ODE-P-spline ---------------------------------------------------#

pars = c(1, 1, 1, 1, 1) # initial parameters as in section 5.2
i = 1
ck = cbind(ck, NULL)
       
theta_tau = c(pars)

crit_gamma = crit_ck = crit_theta_tau = 1
gamma = 1e4

while(((crit_ck > tol_ck) | (crit_gamma > tol_gamma) | (crit_theta_tau > tol_theta_tau)) && (i < 100))
{
  theta_tau_old = theta_tau
  zandpen = c_hat_function(theta = theta_tau[-length(theta_tau)],
                           tau = theta_tau[length(theta_tau)],
                           gamma,
                           ck = ck[, i],
                           length_t,
                           seq_t,
                           B_seq_t,
                           regul = 0.0)

  z = zandpen[[1]]
  pen = zandpen[[2]]
  t_z = t(z)

  y_star = B_0 %*% matrix(z, ncol = 2)
  PEN = (t_z %*% pen $ R %*% z + 2 * t_z %*% pen $ r + pen $ l) 
 
  A = as.matrix(gamma * pen $ R +
                rbind(cbind(tB_B  * theta_tau[length(theta_tau)], tB_B * 0),
                cbind(tB_B * 0, tB_B * theta_tau[length(theta_tau)])))
  solve_A = solve(A, tol = 1e-50)

  ed_1 = sum(diag(B_0 %*% solve_A[1:M, 1:M] %*% (theta_tau[length(theta_tau)] * t_B_0)))
  ed_2 = sum(diag(B_0 %*% solve_A[M + 1:M, M + 1:M] %*% (theta_tau[length(theta_tau)] * t_B_0)))

  theta_tau[length(theta_tau)] = (N_obs - (ed_1 + ed_2)) / sum((y_obs - c(y_star)) ^ 2)

  den = c(PEN / (ed_1 + ed_2))

  gamma_new = 1 / (den + 1e-15)

  crit_gamma = abs((gamma - gamma_new) / gamma)
  gamma = gamma_new

  ck = cbind(ck, z)
  crit_ck = max(abs((ck[, i] - z) / ck[, i]))

  optim_parm = optim(par = theta_tau[-length(theta_tau)],
                     fn = H_fun,
                     tau =  theta_tau[length(theta_tau)],
                     gamma = gamma,
                     ck = z,
                     length_t = length_t,
                     seq_t = seq_t,
                     B_seq_t = B_seq_t,
                     regul = 0.0,
                     method = "BFGS",
                     control = list(fnscale = -1, trace = FALSE),
                     hessian = TRUE)

  theta_tau[-length(theta_tau)] = optim_parm $ par
  FIM = solve(-optim_parm $ hessian)

  crit_theta_tau = max(abs((theta_tau - theta_tau_old) / theta_tau_old))

  cat('iteration:', i,'\n')
  cat('\t', 'crit_gamma:', round(crit_gamma, 8), '\n')
  cat('\t', 'crit_ck:', round(crit_ck, 8), '\n')
  cat('\t', 'crit_theta_tau:', round(crit_theta_tau, 8), '\n')
  cat('\t', 'gamma:', round(gamma, 8), '\n')
  cat('\t', 'tau:', round(tail(theta_tau, n = 1), 8), '\n')
  cat('\t', 'theta:', head(theta_tau, n = -1), '\n')
  
  i = i+1
}
# Out:
# iteration: 1
# 	 crit_gamma: 0.9999564
# 	 crit_ck: 1.520148
# 	 crit_theta_tau: 3.148387
# 	 gamma: 0.4354823
# 	 tau: 3.2e-07
# 	 theta: 0.5543694 -2.148387 0.3178673 2.686912
# iteration: 2
# 	 crit_gamma: 0.9997262
# 	 crit_ck: 8.787551
# 	 crit_theta_tau: 24.17883
# 	 gamma: 0.00011925
# 	 tau: 3.6e-07
# 	 theta: 0.4950072 -0.2214412 -7.367793 4.944586
# iteration: 3
# 	 crit_gamma: 0.7639796
# 	 crit_ck: 4.056261
# 	 crit_theta_tau: 1.30302
# 	 gamma: 2.815e-05
# 	 tau: 7.5e-07
# 	 theta: -0.149997 -0.05088732 -6.782361 5.651707
# iteration: 4
# 	 crit_gamma: 0.509889
# 	 crit_ck: 1.14633
# 	 crit_theta_tau: 22.6479
# 	 gamma: 1.379e-05
# 	 tau: 1.763e-05
# 	 theta: 0.1964102 -8.517441e-05 16.66569 0.07271039
# iteration: 5
# 	 crit_gamma: 7.95157
# 	 crit_ck: 4.374357
# 	 crit_theta_tau: 8.55917
# 	 gamma: 0.00012348
# 	 tau: 9.271e-05
# 	 theta: 0.7222893 0.0006438478 15.69631 0.07724852
# iteration: 6
# 	 crit_gamma: 0.1361022
# 	 crit_ck: 2.912385
# 	 crit_theta_tau: 0.6067696
# 	 gamma: 0.00014029
# 	 tau: 9.243e-05
# 	 theta: 0.6271013 0.001034515 19.10709 0.08044372
# iteration: 7
# 	 crit_gamma: 0.8306495
# 	 crit_ck: 3.876421
# 	 crit_theta_tau: 1.019784
# 	 gamma: 2.376e-05
# 	 tau: 0.00010618
# 	 theta: -0.01240652 0.002077294 17.72192 0.07505525
# iteration: 8
# 	 crit_gamma: 0.7684734
# 	 crit_ck: 2.471968
# 	 crit_theta_tau: 34.92492
# 	 gamma: 5.5e-06
# 	 tau: 9.939e-05
# 	 theta: -0.4457032 0.00483666 13.55736 0.05568307
# iteration: 9
# 	 crit_gamma: 0.8569799
# 	 crit_ck: 2.844745
# 	 crit_theta_tau: 1.110885
# 	 gamma: 7.9e-07
# 	 tau: 0.00012537
# 	 theta: 0.04942166 0.0005477423 11.31244 0.04014843
# iteration: 10
# 	 crit_gamma: 10.17875
# 	 crit_ck: 1.780294
# 	 crit_theta_tau: 53.25315
# 	 gamma: 8.79e-06
# 	 tau: 0.00043626
# 	 theta: 2.681281 0.001847455 12.27778 0.04465292
# iteration: 11
# 	 crit_gamma: 0.09671409
# 	 crit_ck: 3.130982
# 	 crit_theta_tau: 1.728073
# 	 gamma: 7.94e-06
# 	 tau: 0.00022969
# 	 theta: 7.314729 0.003483798 7.988068 0.02894765
# iteration: 12
# 	 crit_gamma: 0.6742655
# 	 crit_ck: 2.465077
# 	 crit_theta_tau: 0.5001366
# 	 gamma: 2.59e-06
# 	 tau: 0.00018022
# 	 theta: 6.334672 0.003854725 3.992942 0.02135356
# iteration: 13
# 	 crit_gamma: 0.4909701
# 	 crit_ck: 1.326525
# 	 crit_theta_tau: 1.026524
# 	 gamma: 3.86e-06
# 	 tau: 0.00036523
# 	 theta: 6.334673 0.003626057 3.992945 0.02247186
# iteration: 14
# 	 crit_gamma: 0.24828
# 	 crit_ck: 1.416646
# 	 crit_theta_tau: 0.4462383
# 	 gamma: 4.82e-06
# 	 tau: 0.00052821
# 	 theta: 6.437869 0.003376852 4.455481 0.0228862
# iteration: 15
# 	 crit_gamma: 0.01645815
# 	 crit_ck: 1.320261
# 	 crit_theta_tau: 0.4798749
# 	 gamma: 4.9e-06
# 	 tau: 0.00078168
# 	 theta: 6.437869 0.003376852 4.455481 0.0228862
# iteration: 16
# 	 crit_gamma: 0.00441306
# 	 crit_ck: 1.334285
# 	 crit_theta_tau: 0.3857788
# 	 gamma: 4.87e-06
# 	 tau: 0.00108323
# 	 theta: 6.437869 0.003376852 4.455481 0.0228862
# iteration: 17
# 	 crit_gamma: 0.00145993
# 	 crit_ck: 1.345757
# 	 crit_theta_tau: 0.3543212
# 	 gamma: 4.87e-06
# 	 tau: 0.00146705
# 	 theta: 6.437869 0.003376852 4.455481 0.0228862
# iteration: 18
# 	 crit_gamma: 0.00581121
# 	 crit_ck: 1.353861
# 	 crit_theta_tau: 0.3183527
# 	 gamma: 4.84e-06
# 	 tau: 0.00193408
# 	 theta: 6.437869 0.003376852 4.455481 0.0228862
# iteration: 19
# 	 crit_gamma: 0.00727861
# 	 crit_ck: 1.357762
# 	 crit_theta_tau: 0.3298272
# 	 gamma: 4.87e-06
# 	 tau: 0.002572
# 	 theta: 6.437869 0.003376852 4.455481 0.0228862
# iteration: 20
# 	 crit_gamma: 0.00837689
# 	 crit_ck: 1.358084
# 	 crit_theta_tau: 0.2906864
# 	 gamma: 4.83e-06
# 	 tau: 0.00331964
# 	 theta: 6.437869 0.003376852 4.455481 0.0228862
# iteration: 21
# 	 crit_gamma: 0.02446055
# 	 crit_ck: 1.434365
# 	 crit_theta_tau: 0.1433285
# 	 gamma: 4.71e-06
# 	 tau: 0.00379544
# 	 theta: 6.437869 0.003353389 4.455481 0.02288661
# iteration: 22
# 	 crit_gamma: 0.05280395
# 	 crit_ck: 1.367292
# 	 crit_theta_tau: 0.3682038
# 	 gamma: 4.96e-06
# 	 tau: 0.00519294
# 	 theta: 6.437869 0.003353389 4.455481 0.02288661
# iteration: 23
# 	 crit_gamma: 0.07494958
# 	 crit_ck: 79.98021
# 	 crit_theta_tau: 0.4983554
# 	 gamma: 4.59e-06
# 	 tau: 0.00398304
# 	 theta: 6.575136 0.001825527 2.945306 0.01148094
# iteration: 24
# 	 crit_gamma: 0.2782773
# 	 crit_ck: 0.7235342
# 	 crit_theta_tau: 3.128394
# 	 gamma: 3.31e-06
# 	 tau: 0.01644355
# 	 theta: 6.575048 0.002995643 2.945042 0.02061134
# iteration: 25
# 	 crit_gamma: 1.588608
# 	 crit_ck: 1.978536
# 	 crit_theta_tau: 2.190773
# 	 gamma: 8.58e-06
# 	 tau: 0.05246762
# 	 theta: 6.575048 0.00299599 2.945042 0.02061108
# iteration: 26
# 	 crit_gamma: 0.01599503
# 	 crit_ck: 2.035087
# 	 crit_theta_tau: 0.3464128
# 	 gamma: 8.44e-06
# 	 tau: 0.06681634
# 	 theta: 6.577217 0.002674055 2.946974 0.01347114
# iteration: 27
# 	 crit_gamma: 0.4178524
# 	 crit_ck: 1.333938
# 	 crit_theta_tau: 1.047899
# 	 gamma: 4.91e-06
# 	 tau: 0.1368331
# 	 theta: 6.544961 0.003675842 2.895685 0.0230425
# iteration: 28
# 	 crit_gamma: 0.1129045
# 	 crit_ck: 10.87257
# 	 crit_theta_tau: 0.3867612
# 	 gamma: 5.47e-06
# 	 tau: 0.089224
# 	 theta: 6.545006 0.003376775 2.895569 0.01413055
# iteration: 29
# 	 crit_gamma: 0.1430154
# 	 crit_ck: 1.13582
# 	 crit_theta_tau: 0.5865872
# 	 gamma: 4.69e-06
# 	 tau: 0.1415617
# 	 theta: 6.545006 0.003376775 2.895569 0.01413055
# iteration: 30
# 	 crit_gamma: 0.09578908
# 	 crit_ck: 1.213187
# 	 crit_theta_tau: 0.6593796
# 	 gamma: 4.24e-06
# 	 tau: 0.2349045
# 	 theta: 6.545006 0.003376775 2.895569 0.01413055
# iteration: 31
# 	 crit_gamma: 0.03919854
# 	 crit_ck: 1.221165
# 	 crit_theta_tau: 0.5828533
# 	 gamma: 4.07e-06
# 	 tau: 0.3718194
# 	 theta: 6.54493 0.003632371 2.895608 0.02209933
# iteration: 32
# 	 crit_gamma: 0.681887
# 	 crit_ck: 1.68194
# 	 crit_theta_tau: 0.4330636
# 	 gamma: 6.85e-06
# 	 tau: 0.4533053
# 	 theta: 6.546297 0.003032878 2.89528 0.01252892
# iteration: 33
# 	 crit_gamma: 0.4615995
# 	 crit_ck: 1.189605
# 	 crit_theta_tau: 0.8816846
# 	 gamma: 3.69e-06
# 	 tau: 0.8529776
# 	 theta: 6.54628 0.003769045 2.895199 0.0224709
# iteration: 34
# 	 crit_gamma: 0.5767931
# 	 crit_ck: 1.832093
# 	 crit_theta_tau: 0.432379
# 	 gamma: 5.81e-06
# 	 tau: 0.8630227
# 	 theta: 6.54633 0.002648774 2.895303 0.01275495
# iteration: 35
# 	 crit_gamma: 0.2396579
# 	 crit_ck: 158.3615
# 	 crit_theta_tau: 0.6372186
# 	 gamma: 4.42e-06
# 	 tau: 1.372562
# 	 theta: 6.546364 0.00367225 2.895258 0.02088265
# iteration: 36
# 	 crit_gamma: 0.2764795
# 	 crit_ck: 1.754785
# 	 crit_theta_tau: 0.4051301
# 	 gamma: 5.64e-06
# 	 tau: 1.307849
# 	 theta: 6.54764 0.002443333 2.894663 0.01242246
# iteration: 37
# 	 crit_gamma: 0.2055594
# 	 crit_ck: 4.39423
# 	 crit_theta_tau: 2.205317
# 	 gamma: 4.48e-06
# 	 tau: 4.19207
# 	 theta: 6.547643 0.003477666 2.894586 0.02271064
# iteration: 38
# 	 crit_gamma: 0.4646755
# 	 crit_ck: 4.151622
# 	 crit_theta_tau: 0.3739203
# 	 gamma: 6.57e-06
# 	 tau: 4.406019
# 	 theta: 6.547643 0.003161941 2.89465 0.01421867
# iteration: 39
# 	 crit_gamma: 0.3423893
# 	 crit_ck: 2.647822
# 	 crit_theta_tau: 0.5854933
# 	 gamma: 4.32e-06
# 	 tau: 5.513815
# 	 theta: 6.547649 0.003619175 2.894661 0.02254361
# iteration: 40
# 	 crit_gamma: 0.5056738
# 	 crit_ck: 1.937411
# 	 crit_theta_tau: 0.4272434
# 	 gamma: 6.5e-06
# 	 tau: 6.088288
# 	 theta: 6.547662 0.002802839 2.894757 0.012912
# iteration: 41
# 	 crit_gamma: 0.279636
# 	 crit_ck: 19.56512
# 	 crit_theta_tau: 0.7403292
# 	 gamma: 4.68e-06
# 	 tau: 10.59563
# 	 theta: 6.547671 0.003718346 2.894754 0.02028413
# iteration: 42
# 	 crit_gamma: 0.1007936
# 	 crit_ck: 1.669521
# 	 crit_theta_tau: 0.3774067
# 	 gamma: 5.15e-06
# 	 tau: 8.876458
# 	 theta: 6.547854 0.002442176 2.895933 0.01262876
# iteration: 43
# 	 crit_gamma: 0.1217243
# 	 crit_ck: 12.66897
# 	 crit_theta_tau: 2.306918
# 	 gamma: 4.53e-06
# 	 tau: 29.35372
# 	 theta: 6.547857 0.003477903 2.895892 0.02264136
# iteration: 44
# 	 crit_gamma: 0.4337077
# 	 crit_ck: 18.01387
# 	 crit_theta_tau: 0.3603094
# 	 gamma: 6.49e-06
# 	 tau: 28.53894
# 	 theta: 6.547862 0.003122979 2.895982 0.01448347
# iteration: 45
# 	 crit_gamma: 0.2873282
# 	 crit_ck: 33.29006
# 	 crit_theta_tau: 0.5134855
# 	 gamma: 4.63e-06
# 	 tau: 24.95253
# 	 theta: 6.547894 0.003716209 2.895995 0.02192052
# iteration: 46
# 	 crit_gamma: 0.2746234
# 	 crit_ck: 1.79007
# 	 crit_theta_tau: 0.4309962
# 	 gamma: 5.9e-06
# 	 tau: 22.36198
# 	 theta: 6.54788 0.002716309 2.896107 0.01247286
# iteration: 47
# 	 crit_gamma: 0.2613057
# 	 crit_ck: 1.190186
# 	 crit_theta_tau: 1.8767
# 	 gamma: 4.36e-06
# 	 tau: 64.3287
# 	 theta: 6.547914 0.003611268 2.89607 0.02285113
# iteration: 48
# 	 crit_gamma: 0.5469219
# 	 crit_ck: 1.949922
# 	 crit_theta_tau: 0.4368358
# 	 gamma: 6.74e-06
# 	 tau: 70.10564
# 	 theta: 6.547904 0.002946548 2.896168 0.01286894
# iteration: 49
# 	 crit_gamma: 0.4448452
# 	 crit_ck: 11.22249
# 	 crit_theta_tau: 0.488558
# 	 gamma: 3.74e-06
# 	 tau: 35.85497
# 	 theta: 6.547904 0.002941847 2.896168 0.01286928
# iteration: 50
# 	 crit_gamma: 0.2200977
# 	 crit_ck: 1.715648
# 	 crit_theta_tau: 2.393382
# 	 gamma: 4.56e-06
# 	 tau: 121.6696
# 	 theta: 6.547778 0.00178028 2.895999 0.01076369
# iteration: 51
# 	 crit_gamma: 0.3200309
# 	 crit_ck: 13.43975
# 	 crit_theta_tau: 2.131644
# 	 gamma: 3.1e-06
# 	 tau: 381.026
# 	 theta: 6.547738 0.00211283 2.895736 0.01096677
# iteration: 52
# 	 crit_gamma: 0.1548803
# 	 crit_ck: 1.96178
# 	 crit_theta_tau: 3.050471
# 	 gamma: 3.58e-06
# 	 tau: 1543.335
# 	 theta: 6.547419 0.004351661 2.895444 0.008020572
# iteration: 53
# 	 crit_gamma: 0.7907468
# 	 crit_ck: 2.216363
# 	 crit_theta_tau: 0.5530136
# 	 gamma: 7.5e-07
# 	 tau: 767.4804
# 	 theta: 6.547948 0.001945134 2.89647 0.008186128
# iteration: 54
# 	 crit_gamma: 0.4303818
# 	 crit_ck: 3.06427
# 	 crit_theta_tau: 0.8993813
# 	 gamma: 1.07e-06
# 	 tau: 77.22285
# 	 theta: 6.547934 0.001627684 2.896447 0.008962249
# iteration: 55
# 	 crit_gamma: 1.21898
# 	 crit_ck: 0.7730405
# 	 crit_theta_tau: 10.80967
# 	 gamma: 2.38e-06
# 	 tau: 911.9766
# 	 theta: 6.548035 0.001584941 2.89611 0.008483676
# iteration: 56
# 	 crit_gamma: 0.2932896
# 	 crit_ck: 1.936968
# 	 crit_theta_tau: 1.316573
# 	 gamma: 1.68e-06
# 	 tau: 1049.158
# 	 theta: 6.551135 -0.0005017496 2.894975 0.006053404
# iteration: 57
# 	 crit_gamma: 0.8575803
# 	 crit_ck: 1.600019
# 	 crit_theta_tau: 0.7481837
# 	 gamma: 2.4e-07
# 	 tau: 264.1952
# 	 theta: 6.551172 -0.0005067416 2.894981 0.006073213
# iteration: 58
# 	 crit_gamma: 0.04724887
# 	 crit_ck: 16048.87
# 	 crit_theta_tau: 0.4422874
# 	 gamma: 2.5e-07
# 	 tau: 148.1248
# 	 theta: 6.551414 -0.0002826162 2.894895 0.006542145
# iteration: 59
# 	 crit_gamma: 0.1258957
# 	 crit_ck: 15.12996
# 	 crit_theta_tau: 3.427684
# 	 gamma: 2.2e-07
# 	 tau: 655.8498
# 	 theta: 6.551976 -0.001214247 2.893661 0.01122557
# iteration: 60
# 	 crit_gamma: 0.9515518
# 	 crit_ck: 421.6527
# 	 crit_theta_tau: 0.9839291
# 	 gamma: 1e-08
# 	 tau: 10.54008
# 	 theta: 6.551931 -0.001814352 2.893772 0.01077608
# iteration: 61
# 	 crit_gamma: 3.846243
# 	 crit_ck: 2532.97
# 	 crit_theta_tau: 0.3406741
# 	 gamma: 5e-08
# 	 tau: 14.13082
# 	 theta: 6.551936 -0.00177615 2.893763 0.01077259
# iteration: 62
# 	 crit_gamma: 5.890767
# 	 crit_ck: 1348.785
# 	 crit_theta_tau: 41.71111
# 	 gamma: 3.5e-07
# 	 tau: 603.543
# 	 theta: 6.55052 -0.001482374 2.89288 0.005759313
# iteration: 63
# 	 crit_gamma: 0.5826716
# 	 crit_ck: 2.004522
# 	 crit_theta_tau: 0.8280406
# 	 gamma: 1.5e-07
# 	 tau: 103.7849
# 	 theta: 6.550591 -0.00139022 2.8928 0.005773844
# iteration: 64
# 	 crit_gamma: 0.1446864
# 	 crit_ck: 27.03023
# 	 crit_theta_tau: 3.939308
# 	 gamma: 1.7e-07
# 	 tau: 512.6255
# 	 theta: 6.550591 -0.00139022 2.8928 0.005773844
# iteration: 65
# 	 crit_gamma: 0.09874635
# 	 crit_ck: 83.36121
# 	 crit_theta_tau: 2.600256
# 	 gamma: 1.9e-07
# 	 tau: 16.64421
# 	 theta: 6.550567 0.002224708 2.892793 0.009224683
# iteration: 66
# 	 crit_gamma: 13.27304
# 	 crit_ck: 114.3161
# 	 crit_theta_tau: 4.955424
# 	 gamma: 2.66e-06
# 	 tau: 99.12332
# 	 theta: 6.550603 0.002628216 2.892806 0.01631032
# iteration: 67
# 	 crit_gamma: 0.8829014
# 	 crit_ck: 153.132
# 	 crit_theta_tau: 0.9728571
# 	 gamma: 3.1e-07
# 	 tau: 2.690495
# 	 theta: 6.550603 0.003552272 2.892815 0.01207598
# iteration: 68
# 	 crit_gamma: 14.12705
# 	 crit_ck: 22.29342
# 	 crit_theta_tau: 12.19551
# 	 gamma: 4.71e-06
# 	 tau: 35.50246
# 	 theta: 6.550601 0.003710009 2.892792 0.01809238
# iteration: 69
# 	 crit_gamma: 0.4389836
# 	 crit_ck: 968.1137
# 	 crit_theta_tau: 0.6758283
# 	 gamma: 2.64e-06
# 	 tau: 11.50889
# 	 theta: 6.550605 0.001891507 2.892853 0.0136109
# iteration: 70
# 	 crit_gamma: 0.1248043
# 	 crit_ck: 88.6282
# 	 crit_theta_tau: 0.4780466
# 	 gamma: 2.97e-06
# 	 tau: 17.01068
# 	 theta: 6.550604 0.002549407 2.892845 0.01371111
# iteration: 71
# 	 crit_gamma: 0.501345
# 	 crit_ck: 412.9873
# 	 crit_theta_tau: 1.316122
# 	 gamma: 4.46e-06
# 	 tau: 39.3988
# 	 theta: 6.550592 0.003592762 2.892803 0.02209955
# iteration: 72
# 	 crit_gamma: 0.3991607
# 	 crit_ck: 44.48265
# 	 crit_theta_tau: 0.6179056
# 	 gamma: 6.24e-06
# 	 tau: 63.74355
# 	 theta: 6.550579 0.002376865 2.892847 0.01561412
# iteration: 73
# 	 crit_gamma: 0.2904842
# 	 crit_ck: 141.6403
# 	 crit_theta_tau: 0.4845735
# 	 gamma: 4.43e-06
# 	 tau: 55.63036
# 	 theta: 6.550561 0.003514354 2.892857 0.02318031
# iteration: 74
# 	 crit_gamma: 0.536196
# 	 crit_ck: 25.58275
# 	 crit_theta_tau: 0.8018812
# 	 gamma: 6.8e-06
# 	 tau: 100.2393
# 	 theta: 6.550591 0.00251189 2.892922 0.01576758
# iteration: 75
# 	 crit_gamma: 0.3275212
# 	 crit_ck: 32.30356
# 	 crit_theta_tau: 0.4667278
# 	 gamma: 4.57e-06
# 	 tau: 81.06618
# 	 theta: 6.550742 0.003684259 2.892878 0.0229288
# iteration: 76
# 	 crit_gamma: 0.4704534
# 	 crit_ck: 7.393434
# 	 crit_theta_tau: 0.6670431
# 	 gamma: 6.73e-06
# 	 tau: 135.1408
# 	 theta: 6.550757 0.002549855 2.892933 0.01581412
# iteration: 77
# 	 crit_gamma: 0.3134297
# 	 crit_ck: 24.63703
# 	 crit_theta_tau: 0.4666871
# 	 gamma: 4.62e-06
# 	 tau: 110.808
# 	 theta: 6.55087 0.00373984 2.892749 0.02237723
# iteration: 78
# 	 crit_gamma: 0.4301992
# 	 crit_ck: 8.312688
# 	 crit_theta_tau: 0.6583577
# 	 gamma: 6.61e-06
# 	 tau: 183.7592
# 	 theta: 6.550893 0.002499547 2.892707 0.0155459
# iteration: 79
# 	 crit_gamma: 0.3249637
# 	 crit_ck: 14.53548
# 	 crit_theta_tau: 0.4673703
# 	 gamma: 4.46e-06
# 	 tau: 149.5847
# 	 theta: 6.550928 0.003589936 2.892896 0.0228116
# iteration: 80
# 	 crit_gamma: 0.4504893
# 	 crit_ck: 6.951193
# 	 crit_theta_tau: 0.604666
# 	 gamma: 6.47e-06
# 	 tau: 240.0335
# 	 theta: 6.550868 0.002420599 2.893064 0.01543348
# iteration: 81
# 	 crit_gamma: 0.3396823
# 	 crit_ck: 54.84995
# 	 crit_theta_tau: 0.3006249
# 	 gamma: 4.27e-06
# 	 tau: 167.8735
# 	 theta: 6.550847 0.00280409 2.893058 0.01593975
# iteration: 82
# 	 crit_gamma: 0.6818739
# 	 crit_ck: 1.231867
# 	 crit_theta_tau: 5.755275
# 	 gamma: 7.18e-06
# 	 tau: 1134.031
# 	 theta: 6.550819 0.002859147 2.893113 0.01593905
# iteration: 83
# 	 crit_gamma: 0.1671342
# 	 crit_ck: 104.6833
# 	 crit_theta_tau: 0.6488989
# 	 gamma: 5.98e-06
# 	 tau: 398.1597
# 	 theta: 6.550987 0.003729467 2.893122 0.01630784
# iteration: 84
# 	 crit_gamma: 0.09439941
# 	 crit_ck: 136.1999
# 	 crit_theta_tau: 0.2319204
# 	 gamma: 5.42e-06
# 	 tau: 375.91
# 	 theta: 6.550981 0.004594407 2.892955 0.01668284
# iteration: 85
# 	 crit_gamma: 0.2993518
# 	 crit_ck: 11.66887
# 	 crit_theta_tau: 0.6295628
# 	 gamma: 3.8e-06
# 	 tau: 612.5689
# 	 theta: 6.550981 0.004594408 2.892955 0.01668284
# iteration: 86
# 	 crit_gamma: 0.05351673
# 	 crit_ck: 10.59956
# 	 crit_theta_tau: 0.378375
# 	 gamma: 4e-06
# 	 tau: 380.7881
# 	 theta: 6.551003 0.004469813 2.893042 0.01661342
# iteration: 87
# 	 crit_gamma: 0.2605313
# 	 crit_ck: 54.17641
# 	 crit_theta_tau: 1.456411
# 	 gamma: 5.04e-06
# 	 tau: 935.372
# 	 theta: 6.550267 0.005171006 2.893047 0.01315223
# iteration: 88
# 	 crit_gamma: 0.6761373
# 	 crit_ck: 9.866002
# 	 crit_theta_tau: 0.5003727
# 	 gamma: 1.63e-06
# 	 tau: 467.3374
# 	 theta: 6.550268 0.005145921 2.893047 0.01316171
# iteration: 89
# 	 crit_gamma: 0.02871738
# 	 crit_ck: 14.35455
# 	 crit_theta_tau: 0.5082953
# 	 gamma: 1.59e-06
# 	 tau: 536.3134
# 	 theta: 6.550813 0.002530274 2.892664 0.0115779
# iteration: 90
# 	 crit_gamma: 2.072805
# 	 crit_ck: 878.0043
# 	 crit_theta_tau: 0.116019
# 	 gamma: 4.87e-06
# 	 tau: 598.5359
# 	 theta: 6.550832 0.002553323 2.892643 0.01159917
# iteration: 91
# 	 crit_gamma: 0.1480122
# 	 crit_ck: 7.858099
# 	 crit_theta_tau: 0.8151282
# 	 gamma: 4.15e-06
# 	 tau: 1086.419
# 	 theta: 6.550832 0.002553323 2.892643 0.01159917
# iteration: 92
# 	 crit_gamma: 0.2101413
# 	 crit_ck: 69.50895
# 	 crit_theta_tau: 0.4797793
# 	 gamma: 5.02e-06
# 	 tau: 565.1779
# 	 theta: 6.550837 0.002536794 2.892654 0.01161441
# iteration: 93
# 	 crit_gamma: 0.1643455
# 	 crit_ck: 23.78693
# 	 crit_theta_tau: 0.7242345
# 	 gamma: 4.2e-06
# 	 tau: 974.4992
# 	 theta: 6.550667 0.002504881 2.892828 0.0109463
# iteration: 94
# 	 crit_gamma: 0.01240242
# 	 crit_ck: 262.8708
# 	 crit_theta_tau: 0.07580227
# 	 gamma: 4.25e-06
# 	 tau: 900.63
# 	 theta: 6.550667 0.002504881 2.892828 0.0109463
# iteration: 95
# 	 crit_gamma: 0.1101068
# 	 crit_ck: 5.079
# 	 crit_theta_tau: 0.7938568
# 	 gamma: 3.78e-06
# 	 tau: 1615.601
# 	 theta: 6.550539 0.002590119 2.892114 0.01041064
# iteration: 96
# 	 crit_gamma: 0.1925718
# 	 crit_ck: 938.0023
# 	 crit_theta_tau: 0.9411115
# 	 gamma: 3.05e-06
# 	 tau: 95.14034
# 	 theta: 6.550561 0.003295782 2.892166 0.01825623
# iteration: 97
# 	 crit_gamma: 1.20732
# 	 crit_ck: 48.398
# 	 crit_theta_tau: 4.679129
# 	 gamma: 6.74e-06
# 	 tau: 540.3142
# 	 theta: 6.550714 0.003703806 2.892119 0.0180828
# iteration: 98
# 	 crit_gamma: 0.1870688
# 	 crit_ck: 203.5568
# 	 crit_theta_tau: 0.3275188
# 	 gamma: 5.48e-06
# 	 tau: 363.3512
# 	 theta: 6.550778 0.004170078 2.892147 0.01784037
# iteration: 99
# 	 crit_gamma: 0.07714484
# 	 crit_ck: 13.45483
# 	 crit_theta_tau: 2.123644
# 	 gamma: 5.9e-06
# 	 tau: 1134.98
# 	 theta: 6.552012 0.003987359 2.890124 0.0142028

# %%
#--------------------------------- plot and approx. std errors ----------------------------------------#

std_err = sqrt(diag(FIM)) # approximate parameter std. error
lev = 0.99
alp = qnorm(1-(1-lev)/2)
sigma = sqrt(1/theta_tau[length(theta_tau)])

par(mfcol = c(2, 1), mar = c(3.5, 3.5, 2, 1), cex.main = 1, mgp = c(2, 0.8, 0))

A = as.matrix(gamma * pen $ R +
                rbind(cbind(tB_B  * theta_tau[length(theta_tau)], tB_B * 0),
                      cbind(tB_B * 0, tB_B * theta_tau[length(theta_tau)])))
solve_A = sigma^2 * solve(A, tol = 1e-50)     

bounds = B_seq_t[[1]] %*% solve_A[1:M, 1:M] %*% t(B_seq_t[[1]] * theta_tau[5])

low_bound = B_seq_t[[1]] %*% ck[1:M, i] - alp * sqrt(diag(bounds))
up_bound = B_seq_t[[1]] %*% ck[1:M, i] + alp * sqrt(diag(bounds))   

plot(t_obs + 1900, y_obs_1, main = "Snowshoe hare",
     xlab = "Time (years)", ylab = "Counts (thousands)", ylim = c(0, 110),
     pch = 16, cex = 1, col = 1)
lines(seq_t + 1900, B_seq_t[[1]] %*% ck[1:M, i], lwd = 2, col = 8)
lines(times + 1900, out[, "x1"], col = 1, lty = 2, lwd = 2)
lines(seq_t + 1900, low_bound, col = 2, lty = 2)
lines(seq_t + 1900, up_bound, col = 2, lty = 2)

points(t_obs + 1900, y_obs_1, col = 1, pch = 16)
legend("top", c("Observations", "Estimated hare dynamics", "Numerical solution",
                    "Std. Err. bands"),
       col = c("black", "gray", "black", "red"), pch = c(16, -1, -1, -1),
       lty = c(0, 1, 2, 2), lwd = c(0, 2, 2, 1), box.lty = 0, cex = 0.8)

bounds = B_seq_t[[1]]  %*% solve_A[M + 1:M, M + 1:M] %*% t(B_seq_t[[1]] * theta_tau[5])

low_bound = B_seq_t[[1]] %*% ck[M + 1:M, i] - alp * sqrt(diag(bounds))
up_bound = B_seq_t[[1]] %*% ck[M + 1:M, i] + alp * sqrt(diag(bounds)) 


plot(t_obs + 1900, y_obs_2, main = "Canadian lynx",
     xlab = "Time (years)", ylab = "Counts (thousands)", ylim = c(0, 80),
     pch = 16, cex = 1, col = 1)
lines(seq_t + 1900, B_seq_t[[1]] %*% ck[M + 1:M, i], lwd = 2, col = 8)
lines(seq_t + 1900, low_bound, col = 2, lty = 2)
lines(seq_t + 1900, up_bound, col = 2, lty = 2)

lines(times + 1900, out[, "x2"], col = 1, lty = 2, lwd = 2)
points(t_obs + 1900, y_obs_2, pch = 16, col = 1)
legend("top", c("Observations", "Estimated lynx dynamics", "Numerical solution",
                    "Std. Err. bands"),
       col = c("black", "gray", "black", "red"), pch = c(16, -1, -1, -1),
       lty = c(0, 1, 2, 2), lwd = c(0, 2, 2, 1), box.lty = 0, cex = 0.8)
# Out:
# Warning message in sqrt(diag(FIM)):
# “NaNs produced”
